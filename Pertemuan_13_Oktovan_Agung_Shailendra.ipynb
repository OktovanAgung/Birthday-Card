# %% [markdown]
# <a href="https://colab.research.google.com/github/OktovanAgung/HBDJunita.github.io/blob/master/Pertemuan_13_Oktovan_Agung_Shailendra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nama           : Oktovan Agung Shailendra
# # NIM            : 312010131
# # Kelas          : TI.20.A.1
# # Matakuliah     : Pengolahan Citra
# # Dosen Pengampu : M. Fatchan,S.Kom,M.Kom, MTCNA
# # Pertemuan      : 13
#
# # Penyaringan dan Pelabelan Ulang

# %%
#Install Package / Module
# !pip install mahotas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mahotas
#   Downloading mahotas-1.4.12-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (5.7 MB)
#      |████████████████████████████████| 5.7 MB 4.0 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mahotas) (1.21.6)
# Installing collected packages: mahotas
# Successfully installed mahotas-1.4.12

# %%
import mahotas as mh
import mahotas.demos
import numpy as np
from pylab import imshow, show

f = mh.demos.nuclear_image()
f = f[:,:,0]
imshow(f)
show()

# %%
f = mh.gaussian_filter(f, 4)
f = (f> f.mean())

# %%
f = mh.gaussian_filter(f, 4)
f = (f> f.mean())
imshow(f)
show()

# %%
labeled, n_nucleus = mh.label(f)
print('Found {} nuclei.'.format(n_nucleus))
# Out:
# Found 40 nuclei.

# %%
labeled, n_nucleus = mh.label(f)
print('Found {} nuclei.'.format(n_nucleus))
imshow(labeled)
show()
# Out:
# Found 40 nuclei.

# %%
sizes = mh.labeled.labeled_size(labeled)
too_big = np.where(sizes > 10000)
labeld = mh.labeled.remove_regions(labeled,too_big)

# %%
sizes = mh.labeled.labeled_size(labeled)
too_big = np.where(sizes > 10000)
labeled = mh.labeled.remove_regions(labeled,too_big)
imshow(labeled)
show()

# %%
labeled = mh.labeled.remove_bordering(labeled)

# %%
labeled = mh.labeled.remove_bordering(labeled)
imshow(labeled)
show()

# %%
relabeled, n_left = mh.labeled.relabel(labeled)
print('after filter and relabeling, there are {} nuclei left.'.format(n_left))
# Out:
# after filter and relabeling, there are 21 nuclei left.

# %%
relabeled, n_left = mh.labeled.relabel(labeled)
print('after filter and relabeling, there are {} nuclei left.'.format(n_left))
imshow(relabeled)
show()
# Out:
# after filter and relabeling, there are 21 nuclei left.
